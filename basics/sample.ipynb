# %%
import pandas as pd

# %%
f_name = []
l_name = []
age = []
mobile = []
email = []
for i in range(2): 
 f_name.append(input('ENTER F_NAME :')) 
 l_name.append(input('ENTER L_NAME :')) 
 age.append(input('ENTER AGE :')) 
 mobile.append(input('ENTER MOBILE NO :')) 
 email.append(input('ENTER EMAIL :')) 
print(f_name ,l_name ,age ,mobile ,email)
# Out:
# ['sarath', 'rahul'] ['sk', 'v'] ['19', '19'] ['98989', '92828'] ['sarath@gmail.com', 'rahul@gmail.com']

# %%
df = pd.DataFrame({'FIRST NAME' : f_name , 'LAST NAME' : l_name , 'AGE' : age ,' MOBILE NO' : mobile , 'EMAIL' : email})
df
# Out:
#   FIRST NAME LAST NAME AGE  MOBILE NO             EMAIL
# 0     sarath        sk  19      98989  sarath@gmail.com
# 1      rahul         v  19      92828   rahul@gmail.com

# %%
item =[1,2,3]
print(item[0])
# Out:
# 1
